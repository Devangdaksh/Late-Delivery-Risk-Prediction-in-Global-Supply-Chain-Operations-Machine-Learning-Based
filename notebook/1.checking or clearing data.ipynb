# %%
import pandas as pd

df = pd.read_csv(file_path, encoding='latin-1')

df.head()
# Out:
#     Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0  DEBIT                         6                              4
# 1  DEBIT                         4                              4
# 2  DEBIT                         4                              4
# 3  DEBIT                         6                              4
# 4  DEBIT                         6                              4
#
#    Benefit per order  Sales per customer   Delivery Status  \
# 0             159.69              472.45     Late delivery
# 1              48.71              167.96  Shipping on time
# 2              87.36              181.99  Shipping on time
# 3             -41.89              175.99     Late delivery
# 4              10.00               40.00     Late delivery
#
#    Late_delivery_risk  Category Id     Category Name Customer City  ...  \
# 0                   1            9  Cardio Equipment   Brownsville  ...
# ...

# %%
df.tail()
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 180514  TRANSFER                         6                              4
# 180515     DEBIT                         2                              4
# 180516     DEBIT                         3                              4
# 180517   PAYMENT                         4                              4
# 180518      CASH                         1                              0
#
#         Benefit per order  Sales per customer   Delivery Status  \
# 180514            -107.96              161.87     Late delivery
# 180515            -126.56              172.66  Advance shipping
# 180516              91.25              314.64  Advance shipping
# 180517               1.53               10.91  Shipping on time
# 180518               9.79               34.98     Late delivery
#
#         Late_delivery_risk  Category Id     Category Name Customer City  ...  \
# ...

# %%
 # Cheacking the  null values in the Dataset
missing_values = df.isnull().sum()
missing_values_percentage = (missing_values / len(df)) * 100
print(f"The Number of Missing Values : {missing_values}")
print(f"The Percentage O=of Missing values : {missing_values_percentage}")
# Out:
# The Number of Missing Values : Type                             0
# Days for shipping (real)         0
# Days for shipment (scheduled)    0
# Benefit per order                0
# Sales per customer               0
# Delivery Status                  0
# Late_delivery_risk               0
# Category Id                      0
# Category Name                    0
# Customer City                    0
# Customer Country                 0
# Customer Fname                   0
# Customer Id                      0
# Customer Lname                   8
# Customer Segment                 0
# Customer State                   0
# Customer Street                  0
# Customer Zipcode                 3
# Department Id                    0
# Department Name                  0
# Latitude                         0
# Longitude                        0
# Market                           0
# Order City                       0
# Order Country                    0
# Order Customer Id                0
# ...

# %%
missing = pd.DataFrame({
    'Missing Values': df.isnull().sum(),
    'Percentage': (df.isnull().sum()/len(df))*100
})

print(missing[missing['Missing Values'] > 0])
# Out:
#                   Missing Values  Percentage
# Customer Lname                 8    0.004432
# Customer Zipcode               3    0.001662

# %%
# Remove rows with missing values
df = df.dropna()

# Verify
print(df.isnull().sum())
# Out:
# Type                             0
# Days for shipping (real)         0
# Days for shipment (scheduled)    0
# Benefit per order                0
# Sales per customer               0
# Delivery Status                  0
# Late_delivery_risk               0
# Category Id                      0
# Category Name                    0
# Customer City                    0
# Customer Country                 0
# Customer Fname                   0
# Customer Id                      0
# Customer Lname                   0
# Customer Segment                 0
# Customer State                   0
# Customer Street                  0
# Customer Zipcode                 0
# Department Id                    0
# Department Name                  0
# Latitude                         0
# Longitude                        0
# Market                           0
# Order City                       0
# Order Country                    0
# Order Customer Id                0
# Order Item Discount              0
# ...

# %%
missing = pd.DataFrame({
    'Missing Values': df.isnull().sum(),
    'Percentage': (df.isnull().sum()/len(df))*100
})

print(missing[missing['Missing Values'] > 0])
# Out:
# Empty DataFrame
# Columns: [Missing Values, Percentage]
# Index: []

# %%
# checking duplicate rows in the dataset
duplicate_rows = df.duplicated().sum()
print(f"Number of duplicate rows: {duplicate_rows}")
# Out:
# Number of duplicate rows: 0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 180508 entries, 0 to 180518
# Data columns (total 40 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Type                           180508 non-null  str
#  1   Days for shipping (real)       180508 non-null  int64
#  2   Days for shipment (scheduled)  180508 non-null  int64
#  3   Benefit per order              180508 non-null  float64
#  4   Sales per customer             180508 non-null  float64
#  5   Delivery Status                180508 non-null  str
#  6   Late_delivery_risk             180508 non-null  int64
#  7   Category Id                    180508 non-null  int64
#  8   Category Name                  180508 non-null  str
#  9   Customer City                  180508 non-null  str
#  10  Customer Country               180508 non-null  str
#  11  Customer Fname                 180508 non-null  str
# ...

# %%
df.describe().T
# Out:
#                                   count          mean           std  \
# Days for shipping (real)       180508.0      3.497673      1.623743
# Days for shipment (scheduled)  180508.0      2.931837      1.374457
# Benefit per order              180508.0     21.971563    104.433860
# Sales per customer             180508.0    183.101749    120.041576
# Late_delivery_risk             180508.0      0.548297      0.497663
# Category Id                    180508.0     31.849270     15.637996
# Customer Id                    180508.0   6690.778857   4162.304984
# Customer Zipcode               180508.0  35920.246698  37542.214613
# Department Id                  180508.0      5.443454      1.629175
# Latitude                       180508.0     29.719858      9.813737
# Longitude                      180508.0    -84.914449     21.432290
# Order Customer Id              180508.0   6690.778857   4162.304984
# Order Item Discount            180508.0     20.663998     21.800753
# ...

# %%
# Save the cleaned dataset as a CSV file
df.to_csv("APL_Logistics_Cleaned.csv", index=False)

print("Cleaned dataset saved successfully as 'APL_Logistics_Cleaned.csv'")
# Out:
# Cleaned dataset saved successfully as 'APL_Logistics_Cleaned.csv'
